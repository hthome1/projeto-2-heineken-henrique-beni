# %% [markdown]
# # Projeto 2 - Classificador Automático de Sentimento
#
# Você foi contratado por uma empresa parar analisar como os clientes estão reagindo a um determinado produto no Twitter. A empresa deseja que você crie um programa que irá analisar as mensagens disponíveis e classificará como "relevante" ou "irrelevante". Com isso ela deseja que mensagens negativas, que denigrem o nome do produto, ou que mereçam destaque, disparem um foco de atenção da área de marketing.<br /><br />
# Como aluno de Ciência dos Dados, você lembrou do Teorema de Bayes, mais especificamente do Classificador Naive-Bayes, que é largamente utilizado em filtros anti-spam de e-mails. O classificador permite calcular qual a probabilidade de uma mensagem ser relevante dadas as palavras em seu conteúdo.<br /><br />
# Para realizar o MVP (*minimum viable product*) do projeto, você precisa implementar uma versão do classificador que "aprende" o que é relevante com uma base de treinamento e compara a performance dos resultados com uma base de testes.<br /><br />
# Após validado, o seu protótipo poderá também capturar e classificar automaticamente as mensagens da plataforma.
#
# ## Informações do Projeto
#
# Prazo: 19/Set até às 23:59.<br />
# Grupo: 2 ou 3 pessoas - grupos com 3 pessoas terá uma rubrica diferenciada.<br /><br />
# Entregáveis via GitHub:
# * Arquivo notebook com o código do classificador, seguindo as orientações abaixo.
# * Arquivo Excel com as bases de treinamento e teste totalmente classificado.
#
# **NÃO gravar a key do professor no arquivo**
#
#
# ### Entrega Intermediária: Check 1 - APS 2
#
# Até o dia 10/Set às 23:59, xlsx deve estar no Github com as seguintes evidências:
#
#   * Produto escolhido.
#   * Arquivo Excel contendo a base de treinamento e a base de testes já classificadas.
#
# Sugestão de leitura:<br />
# https://monkeylearn.com/blog/practical-explanation-naive-bayes-classifier/

# %% [markdown]
# ___
#
# ## Parte I - Adquirindo a Base de Dados
#
# Acessar o notebook **Projeto-2-Planilha** para realizar a coleta dos dados. O grupo deve classificar os dados coletados manualmente.

# %% [markdown]
# ___
# ## Parte II - Montando o Classificador Naive-Bayes
#
# Com a base de treinamento montada, comece a desenvolver o classificador. Não se esqueça de implementar o Laplace Smoothing (https://en.wikipedia.org/wiki/Laplace_smoothing).
#
# Opcionalmente:
# * Limpar as mensagens removendo os caracteres: enter, :, ", ', (, ), etc. Não remover emojis.<br />
# * Corrigir separação de espaços entre palavras e/ou emojis.
# * Propor outras limpezas/transformações que não afetem a qualidade da informação.
#
# Escreva o seu código abaixo:

# %%
import pandas as pd
import json
from random import shuffle
import math
import os.path

# %%
teste = pd.read_excel('tweets_teste.xlsx')
treino = pd.read_excel('tweets_treinamento.xlsx')
treino_indiferente = treino.Treinamento[treino.classificacao == 2]
treino_uteis = treino.Treinamento[treino.classificacao < 2]
tudo_treino = treino.Treinamento
teste_indiferente = teste.Teste[teste.classificacao == 2]
teste_uteis = teste.Teste[teste.classificacao < 2]
tudo_teste = teste.Teste

# %% [markdown]
# ## Limpando os comentários

# %%
def lista(objeto):
    lista=[]
    for i in objeto:
        lista.append(i.split())
    return lista
lista(tudo_teste)
# Out:
# [['uma',
#   'senhorinha',
#   'deu-me',
#   'uma',
#   'mochilinha',
#   'da',
#   'heineken',
#   'as',
#   'senhorinhas',
#   'gostam',
#   'todas',
#   'de',
#   'mim,',
#   'isto',
#   'só',
#   'quer',
#   'dizer',
#   'que',
#   'sou',
#   'fixe'],
#  ['queria',
#   'tá',
#   'falando',
#   '"bom',
#   'dia"',
#   'com',
#   'uma',
#   'heineken',
#   'na',
#   'mão',
#   'como',
#   'foi',
#   'nesse',
#   'feriadão'],
#  ['rt',
#   '@gabriel_motoka:',
#   '#vamosfalarsobrelúpulo',
#   'primeiramente',
#   'skol',
#   'ta',
#   'aguada',
#   'segundamente',
#   'cerveja',
#   'de',
#   'milho',
#   'safada',
#   'terceiramente',
#   '#heineken',
#   'obgd',
#   'p…'],
#  ['tomando', 'heineken', 'querendo', 'que', 'fosse', 'coca', 'cola'],
#  ['rt',
#   '@jesustreep:',
#   'a',
#   'própria',
#   'garota',
#   'propaganda',
#   'da',
#   'heineken',
#   'https://t.co/q3sqydjvob'],
#  ['rt',
#   '@farrley_:',
#   'isso',
#   'é',
#   'coisa',
#   'de',
#   'branco',
#   'bombado',
#   'cabelo',
#   'liso',
#   'topete',
#   'na',
#   'frente',
#   'blusa',
#   'amarrada',
#   'no',
#   'braço',
#   'ou',
#   'entao',
#   'enfiada',
#   'no',
#   'bolso',
#   'da',
#   'bermudinha',
#   'j…'],
#  ['@ffffaleiro', 'tomando', 'uma', 'heineken'],
#  ['rt',
#   '@gabriel_motoka:',
#   '#vamosfalarsobrelúpulo',
#   'primeiramente',
#   'skol',
#   'ta',
#   'aguada',
#   'segundamente',
#   'cerveja',
#   'de',
#   'milho',
#   'safada',
#   'terceiramente',
#   '#heineken',
#   'obgd',
#   'p…'],
#  ['acho',
#   'q',
#   'eu',
#   'preciso',
#   'fazer',
#   'um',
#   'detox',
#   'a',
#   'semana',
#   'toda',
#   'pra',
#   'tirar',
#   'as',
#   'heineken',
#   'e',
#   'as',
#   'frituras',
#   'q',
#   'ingeri',
#   'nesse',
#   'fds'],
#  ['@rhafaellyv',
#   'eu',
#   'tenho',
#   'um',
#   'caso',
#   'com',
#   'ela',
#   'e',
#   'com',
#   'a',
#   'heineken'],
#  ['ouvindo',
#   'o',
#   'rappa,',
#   'bebendo',
#   'heineken,',
#   'e',
#   'trocando',
#   'ideia',
#   'sobre',
#   'a',
#   'vida',
#   'do',
#   'mundo',
#   'com',
#   'o',
#   'meu',
#   'pai,',
#   'madrugada',
#   'perfeita!'],
#  ['rt',
#   '@farrley_:',
#   'isso',
#   'é',
#   'coisa',
#   'de',
#   'branco',
#   'bombado',
#   'cabelo',
#   'liso',
#   'topete',
#   'na',
#   'frente',
#   'blusa',
#   'amarrada',
#   'no',
#   'braço',
#   'ou',
#   'entao',
#   'enfiada',
#   'no',
#   'bolso',
#   'da',
#   'bermudinha',
#   'j…'],
#  ['@y_ninfeta', 'essa', 'heineken', 'na', 'mão', 'aí', 'que', 'delícia!'],
#  ['rt',
#   '@farrley_:',
#   'isso',
#   'é',
#   'coisa',
#   'de',
#   'branco',
#   'bombado',
#   'cabelo',
#   'liso',
#   'topete',
#   'na',
#   'frente',
#   'blusa',
#   'amarrada',
#   'no',
#   'braço',
#   'ou',
#   'entao',
#   'enfiada',
#   'no',
#   'bolso',
#   'da',
#   'bermudinha',
#   'j…'],
#  ['rt',
#   '@farrley_:',
#   'isso',
#   'é',
#   'coisa',
#   'de',
#   'branco',
#   'bombado',
#   'cabelo',
#   'liso',
#   'topete',
#   'na',
#   'frente',
#   'blusa',
#   'amarrada',
#   'no',
#   'braço',
#   'ou',
#   'entao',
#   'enfiada',
#   'no',
#   'bolso',
#   'da',
#   'bermudinha',
#   'j…'],
#  ['o',
#   'melhor',
#   'da',
#   'praia',
#   'é',
#   'que',
#   'a',
#   'heineken',
#   'é',
#   'apenas',
#   '3.70'],
#  ['bebi',
#   'metade',
#   'de',
#   'uma',
#   'caixinha',
#   'de',
#   'eisenbahn',
#   'sozinha',
#   'e',
#   '1',
#   'long',
#   'de',
#   'heineken,',
#   'tô',
#   'loka'],
#  ['rt',
#   '@gabriel_motoka:',
#   '#vamosfalarsobrelúpulo',
#   'primeiramente',
#   'skol',
#   'ta',
#   'aguada',
#   'segundamente',
#   'cerveja',
#   'de',
#   'milho',
#   'safada',
#   'terceiramente',
#   '#heineken',
#   'obgd',
#   'p…'],
#  ['rt',
#   '@farrley_:',
#   'isso',
#   'é',
#   'coisa',
#   'de',
#   'branco',
#   'bombado',
#   'cabelo',
#   'liso',
#   'topete',
#   'na',
#   'frente',
#   'blusa',
#   'amarrada',
#   'no',
#   'braço',
#   'ou',
#   'entao',
#   'enfiada',
#   'no',
#   'bolso',
#   'da',
#   'bermudinha',
#   'j…'],
#  ['hoje',
#   'é',
#   'dia',
#   'de',
#   'palmeiras',
#   '💚🐽',
#   'dia',
#   'de',
#   'resenha',
#   'com',
#   'gamba',
#   'dia',
#   'de',
#   'sair',
#   'com',
#   'seus',
#   'camisa',
#   'do',
#   'verdao',
#   'dia',
#   'de',
#   'tomar',
#   'heineken',
#   'dia',
#   'de',
#   'bandeirao',
#   'na',
#   'sacada',
#   'e',
#   'ofensas',
#   'aos',
#   'rivais',
#   'enfim',
#   ':',
#   'dia',
#   'de',
#   'derby'],
#  ['rt',
#   '@tomfm_:',
#   '@dileyangelo',
#   '@odiodobem',
#   '@juhjuzao',
#   'aposto',
#   'uma',
#   'caixa',
#   'de',
#   'heineken',
#   'que',
#   'o',
#   'jujuzão',
#   'é',
#   'parecido',
#   'com',
#   'isso:',
#   'https://t.co/rwj78r4gup'],
#  ['é',
#   'garota',
#   'propaganda',
#   'heineken',
#   'que',
#   'vcs',
#   'querem?',
#   'então',
#   'toma',
#   'https://t.co/l1qutblkzb'],
#  ['enxuto', 'ta', 'com', 'promo', 'de', 'heineken'],
#  ['rt',
#   '@celsoecon:',
#   '@marcogomes',
#   '@clasarin',
#   'kkkkkkkkkk',
#   'depois',
#   'de',
#   'tomar',
#   'mais',
#   'de',
#   '50',
#   'heineken',
#   'eu',
#   'reconheço',
#   'esse',
#   'dancinha',
#   'fascista',
#   'https://t.co/zjkgra…'],
#  ['2',
#   'baldes',
#   'de',
#   'heineken',
#   'e',
#   '1',
#   'combo',
#   'de',
#   'vodka',
#   'tá',
#   'fazendo',
#   'meu',
#   'teto',
#   'rodar',
#   '😬🙄'],
#  ['peguei',
#   'no',
#   'bolão',
#   'hj',
#   ',',
#   'vou',
#   'lá',
#   'no',
#   'ara',
#   'beber',
#   'umas',
#   'heineken',
#   'pra',
#   'comemora'],
#  ['@leofranca87',
#   '@crisgusmao',
#   'eu',
#   'sou',
#   'do',
#   'time',
#   'da',
#   'holandesa',
#   '(heineken',
#   'é',
#   'muito',
#   'amor)'],
#  ['bebendo',
#   'uma',
#   'heineken,',
#   'comendo',
#   'batata',
#   'e',
#   'assistindo',
#   'desenho'],
#  ['@ruivogabi', 'sem', 'heineken', 'mas', 'com', 'a', 'visão', 'em', 'dia'],
#  ['so', 'queria', 'uma', 'heineken', 'para', 'ver', 'o', 'jogo...'],
#  ['@apequenaursa',
#   'a',
#   'skol',
#   'é',
#   'uma',
#   'marca',
#   'povão.',
#   'sempre',
#   'foi.',
#   'povão',
#   '=',
#   'popular.',
#   'suas',
#   'derivadas',
#   'miram',
#   'outros',
#   'nichos',
#   'mais',
#   'sofisticados.',
#   'pela',
#   'identidade',
#   'visual',
#   'da',
#   'lata',
#   '(verde),',
#   'nota-se',
#   'uma',
#   'rivalidade',
#   'com',
#   'a',
#   'heineken...',
#   'enfim,',
#   'prefiro',
#   'ficar',
#   'na',
#   'amstel',
#   '/',
#   'bud.',
#   'num',
#   'gosto',
#   'de',
#   'cerveja',
#   'amarga.',
#   'hihih',
#   'bem',
#   'menininha.',
#   'https://t.co/mf0e6vmnav'],
#  ['preciso', 'parar', 'de', 'beber......', 'olha,', 'uma', 'heineken'],
#  ['heineken', 'é', 'bem', 'demais'],
#  ['rt',
#   '@farrley_:',
#   'isso',
#   'é',
#   'coisa',
#   'de',
#   'branco',
#   'bombado',
#   'cabelo',
#   'liso',
#   'topete',
#   'na',
#   'frente',
#   'blusa',
#   'amarrada',
#   'no',
#   'braço',
#   'ou',
#   'entao',
#   'enfiada',
#   'no',
#   'bolso',
#   'da',
#   'bermudinha',
#   'j…'],
#  ['rt',
#   '@y_ninfeta:',
#   'cai',
#   'de',
#   'boca',
#   'no',
#   'meu',
#   'bucetão',
#   'aooooo',
#   'https://t.co/cl0kc15uhw'],
#  ['rt',
#   '@farrley_:',
#   'isso',
#   'é',
#   'coisa',
#   'de',
#   'branco',
#   'bombado',
#   'cabelo',
#   'liso',
#   'topete',
#   'na',
#   'frente',
#   'blusa',
#   'amarrada',
#   'no',
#   'braço',
#   'ou',
#   'entao',
#   'enfiada',
#   'no',
#   'bolso',
#   'da',
#   'bermudinha',
#   'j…'],
#  ['solta',
#   'uma',
#   'indireta',
#   'com',
#   'uma',
#   'música',
#   'aí',
#   '—',
#   'quanto',
#   'mais',
#   'desejo,',
#   'o',
#   'queixo',
#   'mais',
#   'cai,',
#   'hey',
#   'hi',
#   'neném',
#   'posso',
#   'te',
#   'pagar',
#   'uma',
#   'heineken?',
#   'https://t.co/nyr2dwnysc'],
#  ['domingo,',
#   'dia',
#   'de',
#   'moer',
#   'uns',
#   'cereais',
#   'e',
#   'beber',
#   'um',
#   'puro',
#   'malte.',
#   'o',
#   '2°',
#   'semestre',
#   'rasgando',
#   'como',
#   'um',
#   'iceberg',
#   'na',
#   'banheira',
#   'e',
#   '2018',
#   'vai',
#   'se',
#   'consolidando',
#   'como',
#   'o',
#   'verdadeiro',
#   'ano',
#   'do',
#   'apocalipse.',
#   'e',
#   'você',
#   'não',
#   'vai',
#   'ficar',
#   'ai',
#   'parado',
#   'deixando',
#   'o',
#   'gelo',
#   'derreter.',
#   '#heineken',
#   'https://t.co/dhydwamssu'],
#  ['um',
#   'barril',
#   'de',
#   'heineken',
#   'foi',
#   'muito',
#   'pouco.',
#   'https://t.co/summenjcv3'],
#  ['meryl',
#   'streep',
#   'acaba',
#   'de',
#   'aparecer',
#   'na',
#   'transmissão',
#   'do',
#   'us',
#   'open',
#   'tomando',
#   'uma',
#   'heineken',
#   'na',
#   'arquibancada.',
#   'que',
#   'mulher!'],
#  ['rt',
#   '@farrley_:',
#   'isso',
#   'é',
#   'coisa',
#   'de',
#   'branco',
#   'bombado',
#   'cabelo',
#   'liso',
#   'topete',
#   'na',
#   'frente',
#   'blusa',
#   'amarrada',
#   'no',
#   'braço',
#   'ou',
#   'entao',
#   'enfiada',
#   'no',
#   'bolso',
#   'da',
#   'bermudinha',
#   'j…'],
#  ['obrigada', 'pelos', 'mimos,', 'heineken'],
#  ['única', 'cerveja', 'que', 'presta', 'é', 'a', 'heineken', '🤘🍻👊'],
#  ['seu',
#   'perfil',
#   'foi',
#   'visto',
#   'por',
#   '3',
#   'pessoas',
#   'nas',
#   'últimas',
#   '2',
#   'horas',
#   'https://t.co/xdup4hopd9'],
#  ['comer',
#   'uma',
#   'pizza',
#   'agora,',
#   'deitar',
#   'e',
#   'dormir.',
#   'acordar',
#   'cedo,',
#   'finalizar',
#   'uma',
#   'venda',
#   'de',
#   '10',
#   'caixas',
#   'de',
#   'heineken',
#   'para',
#   'o',
#   'meu',
#   'amigo',
#   'e',
#   'me',
#   'preparar',
#   'para',
#   'o',
#   'derby',
#   'à',
#   'tarde.',
#   'para',
#   'quem',
#   'estiver',
#   'no',
#   'abc',
#   'eu',
#   'estarei',
#   'em',
#   'algum',
#   'barzinho',
#   'na',
#   'av.',
#   'goiás',
#   '-',
#   'scs',
#   'ou',
#   'figueiras',
#   '-',
#   'st.',
#   'andré.',
#   'boa',
#   'noite!',
#   '👊🏻⚫️⚪️'],
#  ['quando',
#   'já',
#   'tava',
#   'chegando',
#   'perto',
#   'de',
#   'acabar',
#   'a',
#   'festa',
#   'uma',
#   'menina',
#   'pegou',
#   'a',
#   'garrafa',
#   'de',
#   'heineken',
#   'que',
#   'tava',
#   'no',
#   'chão',
#   '(pela',
#   'metade),',
#   'deu',
#   'uma',
#   'gole',
#   '(fez',
#   'carinha',
#   'de',
#   'nojo',
#   'kkkkkkkkk)',
#   'e',
#   'saiu',
#   'cambaleando,',
#   'pagando',
#   'de',
#   'bêbada',
#   '+'],
#  ['@sarassalmeida',
#   '@b_afernanda',
#   'nina',
#   'nina,',
#   'só',
#   'toquei',
#   'na',
#   'heineken',
#   'depois',
#   'do',
#   'ocorrido'],
#  ['2ª',
#   'vez',
#   'que',
#   'tomo',
#   'uma',
#   'heineken',
#   'e',
#   'parece',
#   'que',
#   'levei',
#   'uma',
#   'paulada',
#   'na',
#   'cabeça'],
#  ['rt',
#   '@bhmilgrau:',
#   'a',
#   'origem',
#   'da',
#   'cerveja',
#   'heineken',
#   'por',
#   'um',
#   'mineiro',
#   'https://t.co/l5qd1usnpx'],
#  ['rt',
#   '@farrley_:',
#   'isso',
#   'é',
#   'coisa',
#   'de',
#   'branco',
#   'bombado',
#   'cabelo',
#   'liso',
#   'topete',
#   'na',
#   'frente',
#   'blusa',
#   'amarrada',
#   'no',
#   'braço',
#   'ou',
#   'entao',
#   'enfiada',
#   'no',
#   'bolso',
#   'da',
#   'bermudinha',
#   'j…'],
#  ['rt',
#   '@farrley_:',
#   'isso',
#   'é',
#   'coisa',
#   'de',
#   'branco',
#   'bombado',
#   'cabelo',
#   'liso',
#   'topete',
#   'na',
#   'frente',
#   'blusa',
#   'amarrada',
#   'no',
#   'braço',
#   'ou',
#   'entao',
#   'enfiada',
#   'no',
#   'bolso',
#   'da',
#   'bermudinha',
#   'j…'],
#  ['aff', 'viciada', 'em', 'chop', 'heineken'],
#  ['@mandwis',
#   'foi',
#   'tudo',
#   'na',
#   'garrafa',
#   'de',
#   'whisky',
#   'e',
#   'uma',
#   'caixa',
#   'de',
#   'heineken',
#   'kkkk'],
#  ['minha',
#   'coleção',
#   '😍.',
#   '#heineken',
#   '#heinekenbr',
#   '#polar',
#   '#cerveza',
#   '#cerveja',
#   '#eisebahn',
#   '#estrelagalicia',
#   '#proibida',
#   '#cervejasol',
#   '#cervezasol',
#   '#schin',
#   '#devassa',
#   '#stellaartois',
#   '#brahma',
#   '#brahmaextra',
#   '#bohemia…',
#   'https://t.co/xkiuapqfc6'],
#  ['comprei',
#   'uma',
#   'caixinha',
#   'de',
#   'heineken',
#   'e',
#   'tô',
#   'tomando',
#   'sozinha',
#   '#domingou'],
#  ['rt',
#   '@farrley_:',
#   'isso',
#   'é',
#   'coisa',
#   'de',
#   'branco',
#   'bombado',
#   'cabelo',
#   'liso',
#   'topete',
#   'na',
#   'frente',
#   'blusa',
#   'amarrada',
#   'no',
#   'braço',
#   'ou',
#   'entao',
#   'enfiada',
#   'no',
#   'bolso',
#   'da',
#   'bermudinha',
#   'j…'],
#  ['rt',
#   '@rodpocket:',
#   'fosfobox',
#   '13',
#   'reais',
#   'a',
#   'latinha',
#   'de',
#   'heineken',
#   'e',
#   'eles',
#   'têm',
#   'coragem',
#   'de',
#   'colocar',
#   'detergente',
#   'de',
#   'louça',
#   'no',
#   'dispenser',
#   'de',
#   'sabão',
#   'líquido',
#   'sinc…'],
#  ['já',
#   'tenho',
#   'algo',
#   'em',
#   'comum',
#   'com',
#   'meryl',
#   'que',
#   'é',
#   'ter',
#   'a',
#   'heineken',
#   'como',
#   'fav'],
#  ['é',
#   'uma',
#   'várzea',
#   'essas',
#   'brigas',
#   'heineken',
#   '@scinternacional',
#   'e',
#   '@gremio'],
#  ['@heineken_bra', '@tuliopromoter', 'obrigado', 'seuu', 'gostosooooo', '😍😈😈'],
#  ['rt',
#   '@glaubermacario:',
#   'na',
#   'internet:',
#   '"ain,',
#   'eu',
#   'não',
#   'tomo',
#   'essas',
#   'cervejas',
#   'que',
#   'são',
#   'puro',
#   'milho,',
#   'só',
#   'gosto',
#   'de',
#   'heineken\u200b',
#   'e',
#   'stella".',
#   'no',
#   'bar:',
#   '"ou,',
#   'me',
#   'vê…'],
#  ['rt',
#   '@gabriel_motoka:',
#   '#vamosfalarsobrelúpulo',
#   'primeiramente',
#   'skol',
#   'ta',
#   'aguada',
#   'segundamente',
#   'cerveja',
#   'de',
#   'milho',
#   'safada',
#   'terceiramente',
#   '#heineken',
#   'obgd',
#   'p…'],
#  ['sempre',
#   'gostei',
#   'da',
#   'skol,',
#   'mas',
#   'de',
#   'um',
#   'tempo',
#   'para',
#   'cá',
#   '(2',
#   'anos)',
#   'não',
#   'dá',
#   'para',
#   'beber',
#   'mais.',
#   'só',
#   'heineken.',
#   'https://t.co/0hgas7nsza'],
#  ['comendo',
#   'pão',
#   'de',
#   'queijo,',
#   'dps',
#   'de',
#   'se',
#   'entupir',
#   'de',
#   'bud',
#   'e',
#   'heineken'],
#  ['heineken',
#   'é',
#   'muito',
#   'ruim,',
#   'como',
#   'que',
#   'vocês',
#   'gostam',
#   'disso?',
#   'kk',
#   '🤢'],
#  ['hey', 'nenem,', 'posse', 'te', 'pagar', 'uma', 'heineken?'],
#  ['rt',
#   '@gabriel_motoka:',
#   '#vamosfalarsobrelúpulo',
#   'primeiramente',
#   'skol',
#   'ta',
#   'aguada',
#   'segundamente',
#   'cerveja',
#   'de',
#   'milho',
#   'safada',
#   'terceiramente',
#   '#heineken',
#   'obgd',
#   'p…'],
#  ['por',
#   'isso',
#   'eu',
#   'gosto',
#   'de',
#   'heineken',
#   ',',
#   'se',
#   'toma',
#   'ela',
#   'igual',
#   'um',
#   'fdp',
#   ',',
#   'fica',
#   'loco',
#   ',',
#   'beija',
#   'estranho',
#   ',',
#   'no',
#   'outro',
#   'dia',
#   'a',
#   'única',
#   'ressaca',
#   'que',
#   'vc',
#   'tem',
#   'é',
#   'moral'],
#  ['vagas', 'de', 'emprego', 'nos', 'comentários'],
#  ['meu', 'coroa', 'é', 'fd...', 'só', 'bebe', 'heineken', '😅'],
#  ['auge',
#   'fui',
#   'comprar',
#   'uma',
#   'cerveja',
#   'na',
#   'festinha',
#   'e',
#   'nao',
#   'tinha',
#   'heineken',
#   'e',
#   'nem',
#   'budweiser',
#   'so',
#   'devassa',
#   'eu:',
#   'moça',
#   'eu',
#   'vou',
#   'passar',
#   'mal'],
#  ['resumo',
#   'da',
#   'noite:',
#   'rolê',
#   'de',
#   'bares',
#   'em',
#   'cg,',
#   'amizade',
#   'improvável',
#   'com',
#   'um',
#   'grupo',
#   'de',
#   'policiais',
#   'do',
#   'rj,',
#   'heineken',
#   'geladerrima',
#   'free,',
#   'amiga',
#   'perdeu',
#   'sapato',
#   'e',
#   'o',
#   'garçom',
#   'achou.',
#   'me-mo-rá-vel!'],
#  ['quero',
#   'acordar',
#   'com',
#   'a',
#   'pele',
#   'macia',
#   'assim',
#   'sempre.',
#   'cadê',
#   'cravinho?',
#   'mds',
#   'hahaha',
#   'se',
#   'for',
#   'resultado',
#   'de',
#   'ontem,',
#   'o',
#   'nome',
#   'desse',
#   'milagre',
#   'é',
#   'heineken',
#   'https://t.co/8fbzdmdphs'],
#  ['rt',
#   '@gabriel_motoka:',
#   '#vamosfalarsobrelúpulo',
#   'primeiramente',
#   'skol',
#   'ta',
#   'aguada',
#   'segundamente',
#   'cerveja',
#   'de',
#   'milho',
#   'safada',
#   'terceiramente',
#   '#heineken',
#   'obgd',
#   'p…'],
#  ['rt',
#   '@gabriel_motoka:',
#   '#vamosfalarsobrelúpulo',
#   'primeiramente',
#   'skol',
#   'ta',
#   'aguada',
#   'segundamente',
#   'cerveja',
#   'de',
#   'milho',
#   'safada',
#   'terceiramente',
#   '#heineken',
#   'obgd',
#   'p…'],
#  ['rt',
#   '@gabriel_motoka:',
#   '#vamosfalarsobrelúpulo',
#   'primeiramente',
#   'skol',
#   'ta',
#   'aguada',
#   'segundamente',
#   'cerveja',
#   'de',
#   'milho',
#   'safada',
#   'terceiramente',
#   '#heineken',
#   'obgd',
#   'p…'],
#  ['não',
#   'to',
#   'tendo',
#   'maturidade',
#   'em',
#   'ver',
#   'meu',
#   'pai',
#   'agarrado',
#   'com',
#   'seu',
#   'barril',
#   'de',
#   'heineken...',
#   'que',
#   'homem!',
#   'kkkkkkkk'],
#  ['rt',
#   '@farrley_:',
#   'isso',
#   'é',
#   'coisa',
#   'de',
#   'branco',
#   'bombado',
#   'cabelo',
#   'liso',
#   'topete',
#   'na',
#   'frente',
#   'blusa',
#   'amarrada',
#   'no',
#   'braço',
#   'ou',
#   'entao',
#   'enfiada',
#   'no',
#   'bolso',
#   'da',
#   'bermudinha',
#   'j…'],
#  ['rt',
#   '@farrley_:',
#   'isso',
#   'é',
#   'coisa',
#   'de',
#   'branco',
#   'bombado',
#   'cabelo',
#   'liso',
#   'topete',
#   'na',
#   'frente',
#   'blusa',
#   'amarrada',
#   'no',
#   'braço',
#   'ou',
#   'entao',
#   'enfiada',
#   'no',
#   'bolso',
#   'da',
#   'bermudinha',
#   'j…'],
#  ['ta',
#   'um',
#   'ventinho',
#   'gostoso',
#   'saindo',
#   'da',
#   'janela',
#   'enquanto',
#   'toca',
#   'wonderful',
#   'tonight',
#   'do',
#   'clapton,',
#   'cigarro',
#   'queimando',
#   'no',
#   'cinzeiro,',
#   'long',
#   'de',
#   'heineken',
#   'geladinha,',
#   'meu',
#   'fim',
#   'de',
#   'sábado',
#   'ta',
#   'sossegadinho.'],
#  ['@davicrf5',
#   '@esp_interativo',
#   'eu',
#   'tomo',
#   'brahma,',
#   'heineken',
#   'e',
#   'as',
#   'vezes',
#   'corona.',
#   'o',
#   'aniversario',
#   'é',
#   'dia',
#   '17,',
#   'mas',
#   'obrigado,',
#   'você',
#   'foi',
#   'o',
#   'primeiro',
#   'bicho,',
#   'que',
#   'bacana!',
#   'aushauhs'],
#  ['rt',
#   '@farrley_:',
#   'isso',
#   'é',
#   'coisa',
#   'de',
#   'branco',
#   'bombado',
#   'cabelo',
#   'liso',
#   'topete',
#   'na',
#   'frente',
#   'blusa',
#   'amarrada',
#   'no',
#   'braço',
#   'ou',
#   'entao',
#   'enfiada',
#   'no',
#   'bolso',
#   'da',
#   'bermudinha',
#   'j…'],
#  ['rt',
#   '@gilvanroots:',
#   'domingo,',
#   'dia',
#   'de',
#   'moer',
#   'uns',
#   'cereais',
#   'e',
#   'beber',
#   'um',
#   'puro',
#   'malte.',
#   'o',
#   '2°',
#   'semestre',
#   'rasgando',
#   'como',
#   'um',
#   'iceberg',
#   'na',
#   'banheira',
#   'e',
#   '2018',
#   'vai',
#   'se',
#   'c…'],
#  ['@gilvanroots', '@heineken', '@heinekenbr', 'apoiado', '👊'],
#  ['rt',
#   '@gabriel_motoka:',
#   '#vamosfalarsobrelúpulo',
#   'primeiramente',
#   'skol',
#   'ta',
#   'aguada',
#   'segundamente',
#   'cerveja',
#   'de',
#   'milho',
#   'safada',
#   'terceiramente',
#   '#heineken',
#   'obgd',
#   'p…'],
#  ['rt',
#   '@farrley_:',
#   'isso',
#   'é',
#   'coisa',
#   'de',
#   'branco',
#   'bombado',
#   'cabelo',
#   'liso',
#   'topete',
#   'na',
#   'frente',
#   'blusa',
#   'amarrada',
#   'no',
#   'braço',
#   'ou',
#   'entao',
#   'enfiada',
#   'no',
#   'bolso',
#   'da',
#   'bermudinha',
#   'j…'],
#  ['beber', 'heineken', 'é', 'brabo', 'pprt'],
#  ['e',
#   'na',
#   'europa,',
#   'o',
#   'fascismo',
#   'está',
#   'voltando',
#   'a',
#   'mão',
#   'de',
#   'ferro.',
#   'tendência',
#   'humana',
#   'é',
#   'se',
#   'destruir.',
#   'https://t.co/6k14xozgyt'],
#  ['rt',
#   '@vantetk:',
#   'taekook!au',
#   'onde',
#   'jungkook',
#   'trabalha',
#   'em',
#   'uma',
#   'conveniência',
#   'e',
#   'taehyung',
#   'é',
#   'o',
#   'garoto',
#   'bonito',
#   'da',
#   'heineken',
#   'https://t.co/q1uykmf1r0'],
#  ['rt',
#   '@farrley_:',
#   'isso',
#   'é',
#   'coisa',
#   'de',
#   'branco',
#   'bombado',
#   'cabelo',
#   'liso',
#   'topete',
#   'na',
#   'frente',
#   'blusa',
#   'amarrada',
#   'no',
#   'braço',
#   'ou',
#   'entao',
#   'enfiada',
#   'no',
#   'bolso',
#   'da',
#   'bermudinha',
#   'j…'],
#  ['rt',
#   '@farrley_:',
#   'isso',
#   'é',
#   'coisa',
#   'de',
#   'branco',
#   'bombado',
#   'cabelo',
#   'liso',
#   'topete',
#   'na',
#   'frente',
#   'blusa',
#   'amarrada',
#   'no',
#   'braço',
#   'ou',
#   'entao',
#   'enfiada',
#   'no',
#   'bolso',
#   'da',
#   'bermudinha',
#   'j…'],
#  ['@skol',
#   'foi',
#   'mal',
#   '@skol',
#   'acho',
#   'que',
#   'vocês',
#   'já',
#   'maltrataram',
#   'demais',
#   'o',
#   'paladar',
#   'do',
#   'brasileiro',
#   'com',
#   'seus',
#   'sucos',
#   'de',
#   'milho.',
#   'deixa',
#   'a',
#   'gente',
#   'tomar',
#   'cerveja',
#   'em',
#   'paz.',
#   'manda',
#   'uma',
#   'heineken'],
#  ['um',
#   'dia',
#   'farei',
#   'isso',
#   'para',
#   'minha',
#   'filha',
#   'giovanna',
#   'https://t.co/0dpwfkhsy5'],
#  ['ela', 'deixa', 'heineken', 'gelada', 'pra', 'mim', '❤️'],
#  ['rt',
#   '@farrley_:',
#   'isso',
#   'é',
#   'coisa',
#   'de',
#   'branco',
#   'bombado',
#   'cabelo',
#   'liso',
#   'topete',
#   'na',
#   'frente',
#   'blusa',
#   'amarrada',
#   'no',
#   'braço',
#   'ou',
#   'entao',
#   'enfiada',
#   'no',
#   'bolso',
#   'da',
#   'bermudinha',
#   'j…'],
#  ['@camilagonzo', 'ele,', 'falou', 'que', 'queria', 'beber', '3', 'heineken'],
#  ['rt',
#   '@farrley_:',
#   'isso',
#   'é',
#   'coisa',
#   'de',
#   'branco',
#   'bombado',
#   'cabelo',
#   'liso',
#   'topete',
#   'na',
#   'frente',
#   'blusa',
#   'amarrada',
#   'no',
#   'braço',
#   'ou',
#   'entao',
#   'enfiada',
#   'no',
#   'bolso',
#   'da',
#   'bermudinha',
#   'j…'],
#  ['rt',
#   '@fundacaoestudar:',
#   'heineken',
#   'tem',
#   'processo',
#   'seletivo',
#   'aberto',
#   'para',
#   'programa',
#   'de',
#   'trainee',
#   'que',
#   'desenvolve',
#   'futuros',
#   'líderes',
#   'https://t.co/nmwxtnhqtr'],
#  ['mais',
#   'tarde',
#   'eu',
#   'e',
#   'eliel',
#   'vamos',
#   'tomar',
#   'umasss',
#   'heineken,',
#   'como',
#   'diz',
#   'jéssica',
#   'raideken',
#   'kkkkkkk'],
#  ['eu', 'to', 'chapada', 'de', 'heineken'],
#  ['bolsonaro',
#   'tá',
#   'parecendo',
#   'o',
#   'mosquito',
#   'da',
#   'dengue.',
#   '#muda',
#   '@jairbolsonaro',
#   'precisamos',
#   'de',
#   'um',
#   'presidente',
#   'q',
#   'una',
#   'os',
#   'brasileiros',
#   'de',
#   'bem.',
#   'chega',
#   'dos',
#   'mesmos',
#   'discursos.',
#   'https://t.co/4bbmsqib7i'],
#  ['@paulac_spfc',
#   'o',
#   'portuga',
#   'não',
#   'tem',
#   'heineken,',
#   'estávamos',
#   'no',
#   'do',
#   'lado'],
#  ['rt',
#   '@farrley_:',
#   'isso',
#   'é',
#   'coisa',
#   'de',
#   'branco',
#   'bombado',
#   'cabelo',
#   'liso',
#   'topete',
#   'na',
#   'frente',
#   'blusa',
#   'amarrada',
#   'no',
#   'braço',
#   'ou',
#   'entao',
#   'enfiada',
#   'no',
#   'bolso',
#   'da',
#   'bermudinha',
#   'j…'],
#  ['rt',
#   '@farrley_:',
#   'isso',
#   'é',
#   'coisa',
#   'de',
#   'branco',
#   'bombado',
#   'cabelo',
#   'liso',
#   'topete',
#   'na',
#   'frente',
#   'blusa',
#   'amarrada',
#   'no',
#   'braço',
#   'ou',
#   'entao',
#   'enfiada',
#   'no',
#   'bolso',
#   'da',
#   'bermudinha',
#   'j…'],
#  ['rt',
#   '@farrley_:',
#   'isso',
#   'é',
#   'coisa',
#   'de',
#   'branco',
#   'bombado',
#   'cabelo',
#   'liso',
#   'topete',
#   'na',
#   'frente',
#   'blusa',
#   'amarrada',
#   'no',
#   'braço',
#   'ou',
#   'entao',
#   'enfiada',
#   'no',
#   'bolso',
#   'da',
#   'bermudinha',
#   'j…'],
#  ['baixei',
#   'aplicativo',
#   'do',
#   'supermercado',
#   'aqui',
#   'do',
#   'lado',
#   'de',
#   'casa',
#   'primeira',
#   'aba',
#   '*',
#   'promoçoes',
#   'para',
#   'voce',
#   '*',
#   'heineken',
#   '❌',
#   'r$3,59',
#   '✅',
#   'r$2,89',
#   'eu',
#   'ja',
#   'amo',
#   'esta',
#   'porra'],
#  ['trabalhos',
#   'do',
#   'domingo',
#   'iniciados',
#   'com',
#   'sucesso',
#   '#cerveja',
#   '#beer',
#   '#heineken',
#   'https://t.co/sjbusc9vms',
#   'https://t.co/apokvvgviq'],
#  ['rt',
#   '@glaubermacario:',
#   'na',
#   'internet:',
#   '"ain,',
#   'eu',
#   'não',
#   'tomo',
#   'essas',
#   'cervejas',
#   'que',
#   'são',
#   'puro',
#   'milho,',
#   'só',
#   'gosto',
#   'de',
#   'heineken\u200b',
#   'e',
#   'stella".',
#   'no',
#   'bar:',
#   '"ou,',
#   'me',
#   'vê…'],
#  ['rt',
#   '@farrley_:',
#   'isso',
#   'é',
#   'coisa',
#   'de',
#   'branco',
#   'bombado',
#   'cabelo',
#   'liso',
#   'topete',
#   'na',
#   'frente',
#   'blusa',
#   'amarrada',
#   'no',
#   'braço',
#   'ou',
#   'entao',
#   'enfiada',
#   'no',
#   'bolso',
#   'da',
#   'bermudinha',
#   'j…'],
#  ['rt',
#   '@farrley_:',
#   'isso',
#   'é',
#   'coisa',
#   'de',
#   'branco',
#   'bombado',
#   'cabelo',
#   'liso',
#   'topete',
#   'na',
#   'frente',
#   'blusa',
#   'amarrada',
#   'no',
#   'braço',
#   'ou',
#   'entao',
#   'enfiada',
#   'no',
#   'bolso',
#   'da',
#   'bermudinha',
#   'j…'],
#  ['rt',
#   '@farrley_:',
#   'isso',
#   'é',
#   'coisa',
#   'de',
#   'branco',
#   'bombado',
#   'cabelo',
#   'liso',
#   'topete',
#   'na',
#   'frente',
#   'blusa',
#   'amarrada',
#   'no',
#   'braço',
#   'ou',
#   'entao',
#   'enfiada',
#   'no',
#   'bolso',
#   'da',
#   'bermudinha',
#   'j…'],
#  ['rt',
#   '@farrley_:',
#   'isso',
#   'é',
#   'coisa',
#   'de',
#   'branco',
#   'bombado',
#   'cabelo',
#   'liso',
#   'topete',
#   'na',
#   'frente',
#   'blusa',
#   'amarrada',
#   'no',
#   'braço',
#   'ou',
#   'entao',
#   'enfiada',
#   'no',
#   'bolso',
#   'da',
#   'bermudinha',
#   'j…'],
#  ['@vauseriously',
#   'pelo',
#   'menos',
#   'agora',
#   'vc',
#   'já',
#   'sabe',
#   'o',
#   'que',
#   'é',
#   'heineken',
#   'e',
#   'não',
#   'compra',
#   'mais',
#   'achando',
#   'que',
#   'é',
#   'outra',
#   'coisa'],
#  ['@apequenaursa',
#   'dá',
#   'sim.',
#   'cê',
#   'vai',
#   'gostar!',
#   'ela',
#   'não',
#   'empapuça.',
#   'agora',
#   'a',
#   'heineken,',
#   'mel',
#   'dels,',
#   'parece',
#   'dipirona...',
#   'só',
#   'tomo',
#   'se',
#   'for',
#   'com',
#   'pedras',
#   'de',
#   'gelo.',
#   'igual',
#   'a',
#   'stela...',
#   'ah,',
#   'tbm',
#   'tomo',
#   'skol',
#   'no',
#   'boteco',
#   'do',
#   'bairro...',
#   'hihi',
#   'https://t.co/8bq6ut5ric'],
#  ['vamos',
#   'falar',
#   'a',
#   'verdade.',
#   'onde',
#   'houveram',
#   'comunistas',
#   'que',
#   '"lutaram',
#   'pela',
#   'liberdade",',
#   'nunca',
#   'houve',
#   'democracia,',
#   'por',
#   'exemplo',
#   'em',
#   'cuba,',
#   'china,',
#   'russia,',
#   'camboja,',
#   'angola,',
#   'venezuela...',
#   'capitalismo',
#   'é',
#   'uma',
#   'merda',
#   'mas',
#   'o',
#   'comunismo',
#   'é',
#   'pior...',
#   'https://t.co/rf46xkbmv9'],
#  ['heineken,', 'te', 'quero', 'muito!', 'muuuuito!!'],
#  ['tava',
#   'a',
#   '3',
#   'semanas',
#   'sem',
#   'beber',
#   'cerveja',
#   'ai',
#   'ontem',
#   'tomei',
#   'uma',
#   'heineken',
#   'quente',
#   'e',
#   'porra',
#   'desceu',
#   'que',
#   'nem',
#   'mel'],
#  ['é', 'oficial:', 'heineken', 'é', 'a', 'pior', 'cerveja', 'do', 'mundo'],
#  ['protesto',
#   'inútil',
#   'é',
#   'vcs',
#   'ficarem',
#   'lá',
#   'na',
#   'praça',
#   'da',
#   'bicicleta',
#   'tomando',
#   'heineken',
#   'chamando',
#   'haddad',
#   'de',
#   'crush'],
#  ['@badickecrf', 'dnv???', 'taquei', '3', 'packs', 'de', 'heineken', 'ontem'],
#  ['rt',
#   '@farrley_:',
#   'isso',
#   'é',
#   'coisa',
#   'de',
#   'branco',
#   'bombado',
#   'cabelo',
#   'liso',
#   'topete',
#   'na',
#   'frente',
#   'blusa',
#   'amarrada',
#   'no',
#   'braço',
#   'ou',
#   'entao',
#   'enfiada',
#   'no',
#   'bolso',
#   'da',
#   'bermudinha',
#   'j…'],
#  ['você',
#   'pode',
#   'assinar',
#   'e',
#   'ajudar',
#   'douglas',
#   'renan',
#   'meneghelli?',
#   'https://t.co/1pyhtvmkb1'],
#  ['rt',
#   '@vicente_fut:',
#   'percebo',
#   'que',
#   'to',
#   'ficando',
#   'velho',
#   'quando',
#   'o',
#   'pião',
#   'que',
#   'faz',
#   'minha',
#   'brisa',
#   'é',
#   'resenha',
#   'num',
#   'barzinho,',
#   'tomando',
#   'uma',
#   'heineken',
#   'e',
#   'comendo',
#   'boli…'],
#  ['vai', 'descer', 'heineken', 'pelo', 'centro'],
#  ['eu',
#   'e',
#   'étori',
#   'fomos',
#   'tomar',
#   'uma',
#   'cervejinha',
#   'de',
#   'leve',
#   'e',
#   'no',
#   'final',
#   'tomamos',
#   '14',
#   'garrafas',
#   'de',
#   'heineken...',
#   'eu',
#   'amo',
#   'meu',
#   'namoro,',
#   'na',
#   'moral'],
#  ['tá', 'rolando', 'a', 'heineken', '😅'],
#  ['vai',
#   'tomar',
#   'no',
#   'cú,',
#   'rosberg',
#   'tá',
#   'no',
#   'comercial',
#   'da',
#   'heineken',
#   'o',
#   'fdp',
#   'só',
#   'ganhou',
#   'um',
#   'prêmio',
#   'e',
#   'parou',
#   'de',
#   'correr',
#   'pra',
#   'virar',
#   'garoto',
#   'propaganda',
#   '@nico_rosberg',
#   'te',
#   'odeio',
#   'fortemente.'],
#  ['rt',
#   '@farrley_:',
#   'isso',
#   'é',
#   'coisa',
#   'de',
#   'branco',
#   'bombado',
#   'cabelo',
#   'liso',
#   'topete',
#   'na',
#   'frente',
#   'blusa',
#   'amarrada',
#   'no',
#   'braço',
#   'ou',
#   'entao',
#   'enfiada',
#   'no',
#   'bolso',
#   'da',
#   'bermudinha',
#   'j…'],
#  ['@kassius_kleyton',
#   'meu',
#   'pai',
#   'é',
#   'um',
#   'tiozão',
#   'ent,',
#   'ele',
#   'faz',
#   'tudo',
#   'isso',
#   'aí',
#   'kkkkkkkkkkk',
#   'só',
#   'q',
#   'no',
#   'lugar',
#   'da',
#   'glacial',
#   'é',
#   'heineken'],
#  ['@drunkfootbaiier',
#   '@gkpataro',
#   'hauhauahuahau',
#   'olha',
#   'ai',
#   'tomou',
#   'muita',
#   'heineken',
#   'o',
#   'garoto',
#   'propaganda'],
#  ['rt',
#   '@farrley_:',
#   'isso',
#   'é',
#   'coisa',
#   'de',
#   'branco',
#   'bombado',
#   'cabelo',
#   'liso',
#   'topete',
#   'na',
#   'frente',
#   'blusa',
#   'amarrada',
#   'no',
#   'braço',
#   'ou',
#   'entao',
#   'enfiada',
#   'no',
#   'bolso',
#   'da',
#   'bermudinha',
#   'j…'],
#  ['rt',
#   '@farrley_:',
#   'isso',
#   'é',
#   'coisa',
#   'de',
#   'branco',
#   'bombado',
#   'cabelo',
#   'liso',
#   'topete',
#   'na',
#   'frente',
#   'blusa',
#   'amarrada',
#   'no',
#   'braço',
#   'ou',
#   'entao',
#   'enfiada',
#   'no',
#   'bolso',
#   'da',
#   'bermudinha',
#   'j…'],
#  ['hey!', 'hi,', 'neném', 'posso', 'te', 'pagar', 'uma', 'heineken?'],
#  ['rt',
#   '@farrley_:',
#   'isso',
#   'é',
#   'coisa',
#   'de',
#   'branco',
#   'bombado',
#   'cabelo',
#   'liso',
#   'topete',
#   'na',
#   'frente',
#   'blusa',
#   'amarrada',
#   'no',
#   'braço',
#   'ou',
#   'entao',
#   'enfiada',
#   'no',
#   'bolso',
#   'da',
#   'bermudinha',
#   'j…'],
#  ['para',
#   'quem',
#   'entende,',
#   'os',
#   'suportes',
#   'descascados',
#   'e',
#   'os',
#   'equipamentos',
#   '“simples”',
#   'deixam',
#   'claro',
#   'que',
#   'a',
#   'santa',
#   'casa',
#   'de',
#   'juiz',
#   'de',
#   'fora,',
#   'assim',
#   'como',
#   'quase',
#   'todas',
#   'do',
#   'brasil,',
#   'sofre',
#   'com',
#   'o',
#   'baixíssimo',
#   'investimento',
#   'em',
#   'saúde.',
#   'jair',
#   'bolsonaro,...',
#   'https://t.co/ksnsq49fab'],
#  ['heineken',
#   'piriguete',
#   'é',
#   'a',
#   'melhor',
#   'coisa',
#   'q',
#   'existe',
#   'bebivel'],
#  ['nem',
#   'bebi',
#   'muito',
#   'assim,',
#   'só',
#   'uns',
#   'três',
#   'copos',
#   'de',
#   'catuaba,',
#   'uma',
#   'heineken,',
#   'coca',
#   'cola',
#   'com',
#   'vodka',
#   'e',
#   'esperimentei',
#   'skol',
#   'beats',
#   'e',
#   'hops'],
#  ['@htinhadauol',
#   'a',
#   '1°',
#   'coisa',
#   'q',
#   'eu',
#   'reparei',
#   'na',
#   'ft',
#   'é',
#   'q',
#   'ces',
#   'tão',
#   'bebendo',
#   'itaipava,',
#   'cerveja',
#   'ja',
#   'é',
#   'meio',
#   'ruim..',
#   'essa',
#   'ent',
#   'vish..',
#   'sou',
#   '+',
#   'uma',
#   'heineken',
#   'o',
#   'antartica',
#   ':v'],
#  ['rt',
#   '@umsobrio_:',
#   'vamo',
#   'acordar',
#   'porque',
#   'as',
#   'latinha',
#   'de',
#   'heineken',
#   'não',
#   'vão',
#   'se',
#   'esvaziar',
#   'sozinhas!'],
#  ['heineken', '7', 'reais', 'me', 'fudeu'],
#  ['@fabioporchat',
#   '@skol',
#   'faz',
#   'com',
#   'a',
#   '@heinekenbr',
#   'que',
#   'é',
#   'cerveja',
#   'de',
#   'verdade!',
#   '@heineken_sa',
#   '@heineken'],
#  ['meu',
#   'eterno',
#   'candidato',
#   'cristovam',
#   'buarque',
#   'https://t.co/n8nxbz3woq'],
#  ['e',
#   'a',
#   'bala',
#   'bala',
#   'q',
#   'eu',
#   'tomei',
#   'ontem',
#   'pra',
#   'frita',
#   'que',
#   'era',
#   'verde',
#   'e',
#   'tava',
#   'escrito',
#   'heineken',
#   'tem',
#   'inovação',
#   'nas',
#   'droga',
#   'pq',
#   'o',
#   'capitalismo',
#   'faz',
#   'os',
#   'vendedor',
#   'pensar',
#   'diferenciado'],
#  ['@heineken_bra',
#   'eles',
#   'crescer',
#   'mas',
#   'nao',
#   '..',
#   'hahah',
#   'sao',
#   'tao',
#   'pequenos',
#   'cabe',
#   'em',
#   'roupa',
#   'nem',
#   'uma',
#   'kkk',
#   'coloquei',
#   'na',
#   'cabeça',
#   'quero',
#   'coloca',
#   'kk',
#   'acho',
#   'tao',
#   'lindo...',
#   'xiii',
#   'ate',
#   'os',
#   '40',
#   'ta',
#   'longe',
#   'homem',
#   'kkk'],
#  ['rt',
#   '@farrley_:',
#   'isso',
#   'é',
#   'coisa',
#   'de',
#   'branco',
#   'bombado',
#   'cabelo',
#   'liso',
#   'topete',
#   'na',
#   'frente',
#   'blusa',
#   'amarrada',
#   'no',
#   'braço',
#   'ou',
#   'entao',
#   'enfiada',
#   'no',
#   'bolso',
#   'da',
#   'bermudinha',
#   'j…'],
#  ['rt',
#   '@farrley_:',
#   'isso',
#   'é',
#   'coisa',
#   'de',
#   'branco',
#   'bombado',
#   'cabelo',
#   'liso',
#   'topete',
#   'na',
#   'frente',
#   'blusa',
#   'amarrada',
#   'no',
#   'braço',
#   'ou',
#   'entao',
#   'enfiada',
#   'no',
#   'bolso',
#   'da',
#   'bermudinha',
#   'j…'],
#  ['mano,', 'que', 'heineken', 'foi', 'essaaaaa??', 'kkk'],
#  ['rt',
#   '@farrley_:',
#   'isso',
#   'é',
#   'coisa',
#   'de',
#   'branco',
#   'bombado',
#   'cabelo',
#   'liso',
#   'topete',
#   'na',
#   'frente',
#   'blusa',
#   'amarrada',
#   'no',
#   'braço',
#   'ou',
#   'entao',
#   'enfiada',
#   'no',
#   'bolso',
#   'da',
#   'bermudinha',
#   'j…'],
#  ['mano',
#   'eu',
#   'tenho',
#   'vontade',
#   'de',
#   'beber',
#   'heineken',
#   'skol',
#   'beats',
#   'e',
#   'stella',
#   'artois',
#   'p',
#   'saber',
#   'como',
#   'é'],
#  ['eu',
#   'expliquei',
#   'que',
#   'era',
#   'uma',
#   'biri',
#   ',',
#   'não',
#   'era',
#   'uma',
#   'heineken'],
#  ['melhor', 'cerveja', 'e', 'a', 'heineken', 'sem', 'dúvidas'],
#  ['@blogolhonamira',
#   '@rodrigopoet4',
#   'geladeira',
#   'cheiam',
#   'e,',
#   'de',
#   'preferência,',
#   'de',
#   'cerveja',
#   'de',
#   '1ª',
#   'linha.',
#   'nada',
#   'de',
#   'skol.',
#   'brahma;',
#   'tem',
#   'que',
#   'ser',
#   'de',
#   'heineken',
#   'pra',
#   'cima.'],
#  ['alguém',
#   'sabe',
#   'de',
#   'algum',
#   'supermercado',
#   'aberto',
#   'hoje?',
#   'ou',
#   'aonde',
#   'que',
#   'venda',
#   'heineken'],
#  ['rt',
#   '@gabriel_motoka:',
#   '#vamosfalarsobrelúpulo',
#   'primeiramente',
#   'skol',
#   'ta',
#   'aguada',
#   'segundamente',
#   'cerveja',
#   'de',
#   'milho',
#   'safada',
#   'terceiramente',
#   '#heineken',
#   'obgd',
#   'p…'],
#  ['@gabriel_motoka',
#   'eu',
#   'gosto',
#   'muito',
#   'da',
#   'heineken.',
#   'mas',
#   'acreditaria',
#   'que',
#   'é',
#   '100%',
#   'puro',
#   'malte',
#   'mesmo,',
#   'so',
#   'acompanhando',
#   'o',
#   'processo.',
#   'é',
#   'que',
#   'eu',
#   'sou',
#   'mineirinho',
#   'brother,',
#   'desconfiado',
#   'pra',
#   'caraio'],
#  ['pelo',
#   'menos',
#   'comprei',
#   'uma',
#   'batata',
#   'do',
#   'mac',
#   'e',
#   'duas',
#   'heineken',
#   ';)'],
#  ['em',
#   'fortaleza',
#   'o',
#   'clima',
#   'segue',
#   'instável',
#   'e',
#   'propício',
#   'para',
#   'muita',
#   'heineken',
#   'e',
#   'praia,',
#   'pois',
#   'segunda',
#   'também',
#   'é',
#   'dia',
#   '☀️🏖🍻',
#   'https://t.co/yhhyf23u0z'],
#  ['rt',
#   '@farrley_:',
#   'isso',
#   'é',
#   'coisa',
#   'de',
#   'branco',
#   'bombado',
#   'cabelo',
#   'liso',
#   'topete',
#   'na',
#   'frente',
#   'blusa',
#   'amarrada',
#   'no',
#   'braço',
#   'ou',
#   'entao',
#   'enfiada',
#   'no',
#   'bolso',
#   'da',
#   'bermudinha',
#   'j…'],
#  ['to',
#   'nervosa...',
#   'apostei',
#   'um',
#   'fardo',
#   'de',
#   'heineken',
#   'com',
#   'palmeirense',
#   '🙄'],
#  ['começando',
#   'os',
#   'trabalhos',
#   '(@',
#   'heineken',
#   'brasil',
#   'in',
#   'são',
#   'paulo)',
#   'https://t.co/dqc8qafqhw'],
#  ['rt',
#   '@farrley_:',
#   'isso',
#   'é',
#   'coisa',
#   'de',
#   'branco',
#   'bombado',
#   'cabelo',
#   'liso',
#   'topete',
#   'na',
#   'frente',
#   'blusa',
#   'amarrada',
#   'no',
#   'braço',
#   'ou',
#   'entao',
#   'enfiada',
#   'no',
#   'bolso',
#   'da',
#   'bermudinha',
#   'j…'],
#  ['rt',
#   '@farrley_:',
#   'isso',
#   'é',
#   'coisa',
#   'de',
#   'branco',
#   'bombado',
#   'cabelo',
#   'liso',
#   'topete',
#   'na',
#   'frente',
#   'blusa',
#   'amarrada',
#   'no',
#   'braço',
#   'ou',
#   'entao',
#   'enfiada',
#   'no',
#   'bolso',
#   'da',
#   'bermudinha',
#   'j…'],
#  ['rt',
#   '@farrley_:',
#   'isso',
#   'é',
#   'coisa',
#   'de',
#   'branco',
#   'bombado',
#   'cabelo',
#   'liso',
#   'topete',
#   'na',
#   'frente',
#   'blusa',
#   'amarrada',
#   'no',
#   'braço',
#   'ou',
#   'entao',
#   'enfiada',
#   'no',
#   'bolso',
#   'da',
#   'bermudinha',
#   'j…'],
#  ['@vieiralivia_', 'posso', 'te', 'pagar', 'uma', 'heineken', '🎶'],
#  ['pena',
#   'q',
#   'é',
#   'heineken,',
#   'mas',
#   'bebo',
#   'do',
#   'msm',
#   'jeito',
#   'e',
#   'fdc'],
#  ['@akamarsulo',
#   '1/4',
#   'de',
#   'um',
#   'corote',
#   'e',
#   '1',
#   'latinha',
#   'de',
#   'heineken'],
#  ['rt',
#   '@farrley_:',
#   'isso',
#   'é',
#   'coisa',
#   'de',
#   'branco',
#   'bombado',
#   'cabelo',
#   'liso',
#   'topete',
#   'na',
#   'frente',
#   'blusa',
#   'amarrada',
#   'no',
#   'braço',
#   'ou',
#   'entao',
#   'enfiada',
#   'no',
#   'bolso',
#   'da',
#   'bermudinha',
#   'j…'],
#  ['rt',
#   '@farrley_:',
#   'isso',
#   'é',
#   'coisa',
#   'de',
#   'branco',
#   'bombado',
#   'cabelo',
#   'liso',
#   'topete',
#   'na',
#   'frente',
#   'blusa',
#   'amarrada',
#   'no',
#   'braço',
#   'ou',
#   'entao',
#   'enfiada',
#   'no',
#   'bolso',
#   'da',
#   'bermudinha',
#   'j…'],
#  ['rt',
#   '@kakapassos:',
#   '@gilvanroots',
#   '@heineken',
#   '@heinekenbr',
#   'boraaaa',
#   '😉',
#   'feliz',
#   'domingo',
#   'gil',
#   'https://t.co/lend323kww'],
#  ['as',
#   'marcas',
#   'de',
#   'cervejas',
#   'que',
#   'me',
#   'perdoem',
#   'mas',
#   'não',
#   'consigo.',
#   'escolher',
#   'entre',
#   'sagres,',
#   'super',
#   'bock,',
#   'carlsberg',
#   'ou',
#   'heineken',
#   'é',
#   'praticamente',
#   'o',
#   'mesmo',
#   'que',
#   'me',
#   'pedirem',
#   'para',
#   'escolher',
#   'um',
#   'esparguete',
#   'do',
#   'continente,',
#   'pingo',
#   'doce',
#   'ou',
#   'do',
#   'jumbo.',
#   'sei',
#   'que',
#   'são',
#   'diferentes',
#   'mas',
#   'atribuir-lhes',
#   'valores',
#   'de',
#   'diferen…',
#   'https://t.co/shoyjwbxd7'],
#  ['sou',
#   'a',
#   'única',
#   'que',
#   'tem',
#   'um',
#   'pé',
#   'de',
#   'heineken',
#   'https://t.co/ocs5qqeyv8'],
#  ['n',
#   'sei',
#   'oq',
#   'era',
#   'mais',
#   'da',
#   'hr,',
#   'o',
#   'pia',
#   'loko',
#   'deitado',
#   'no',
#   'colchão',
#   'ou',
#   'o',
#   'carro',
#   'da',
#   'heineken'],
#  ['@marcipiccola',
#   'uai,',
#   'outra',
#   'brahma???',
#   'quero',
#   'heineken,',
#   'serra',
#   'malte,',
#   '1500,',
#   'capitão',
#   'senra',
#   'kkkkkk'],
#  ['@gserrano',
#   '@startupdareal',
#   'já',
#   'temos',
#   'informações',
#   'suficientes',
#   'para',
#   'descobrir',
#   'a',
#   'identidade',
#   'secreta',
#   'da',
#   'startupdareal.',
#   'mulher',
#   'atua',
#   'quase',
#   '15',
#   'anos',
#   'na',
#   'área',
#   'de',
#   'ti',
#   'formada',
#   'em',
#   'física',
#   'bebe',
#   'heineken.'],
#  ['comecei',
#   'a',
#   'tomar',
#   'às',
#   '13h',
#   'quando',
#   'vi',
#   'tava',
#   'na',
#   'décima',
#   'segunda',
#   'heineken',
#   'é',
#   'já',
#   'tava',
#   'tudo',
#   'embaçado....',
#   'bons',
#   'tempos',
#   'quando',
#   'meu',
#   'era',
#   'forte',
#   '💔'],
#  ['rt',
#   '@jorgetemer:',
#   '@blogolhonamira',
#   '@rodrigopoet4',
#   'geladeira',
#   'cheiam',
#   'e,',
#   'de',
#   'preferência,',
#   'de',
#   'cerveja',
#   'de',
#   '1ª',
#   'linha.',
#   'nada',
#   'de',
#   'skol.',
#   'brahma;',
#   'tem',
#   'que',
#   'ser…'],
#  ['nem', 'beber', 'heineken', 'tá', 'me', 'animando'],
#  ['meryl',
#   'apreciando',
#   'uma',
#   'heineken',
#   'passando',
#   'na',
#   'sua',
#   'timeline',
#   '#usopenfinal',
#   'https://t.co/bkfegrkdz1'],
#  ['rt',
#   '@farrley_:',
#   'isso',
#   'é',
#   'coisa',
#   'de',
#   'branco',
#   'bombado',
#   'cabelo',
#   'liso',
#   'topete',
#   'na',
#   'frente',
#   'blusa',
#   'amarrada',
#   'no',
#   'braço',
#   'ou',
#   'entao',
#   'enfiada',
#   'no',
#   'bolso',
#   'da',
#   'bermudinha',
#   'j…'],
#  ['heineken',
#   'tem',
#   'processo',
#   'seletivo',
#   'aberto',
#   'para',
#   'programa',
#   'de',
#   'trainee',
#   'que',
#   'desenvolve',
#   'futuros',
#   'líderes',
#   'https://t.co/nmwxtnhqtr'],
#  ['meu',
#   'domingo',
#   'está',
#   'lindo',
#   'com',
#   'essa',
#   'dupla',
#   'canelinha',
#   'x',
#   'heineken',
#   'i',
#   'love',
#   'you!',
#   'https://t.co/1e4wyzqxpm'],
#  ['rt',
#   '@farrley_:',
#   'isso',
#   'é',
#   'coisa',
#   'de',
#   'branco',
#   'bombado',
#   'cabelo',
#   'liso',
#   'topete',
#   'na',
#   'frente',
#   'blusa',
#   'amarrada',
#   'no',
#   'braço',
#   'ou',
#   'entao',
#   'enfiada',
#   'no',
#   'bolso',
#   'da',
#   'bermudinha',
#   'j…'],
#  ['as',
#   'lembranças',
#   'do',
#   'date',
#   'ajnda',
#   'estão',
#   'vivissima',
#   'tipo',
#   'as',
#   'duas',
#   'garrafas',
#   'de',
#   'heineken',
#   'que',
#   'a',
#   'gente',
#   'deixou',
#   'do',
#   'ladinho',
#   'do',
#   'lixo',
#   'do',
#   'ponto',
#   'pq',
#   'tava',
#   'lotado'],
#  ['rt',
#   '@farrley_:',
#   'isso',
#   'é',
#   'coisa',
#   'de',
#   'branco',
#   'bombado',
#   'cabelo',
#   'liso',
#   'topete',
#   'na',
#   'frente',
#   'blusa',
#   'amarrada',
#   'no',
#   'braço',
#   'ou',
#   'entao',
#   'enfiada',
#   'no',
#   'bolso',
#   'da',
#   'bermudinha',
#   'j…'],
#  ['me', 'chamem', 'de', 'menino', 'heineken'],
#  ['@rf_ofc',
#   'heineken',
#   'agr',
#   'só',
#   'qndo',
#   'eu',
#   'começar',
#   'a',
#   'apreciar'],
#  ['acabei',
#   'de',
#   'ver',
#   'uma',
#   'foto',
#   'de',
#   'uma',
#   'heineken',
#   'geladinha',
#   'e',
#   'bateu',
#   'aquela',
#   'vontade'],
#  ['rt',
#   '@farrley_:',
#   'isso',
#   'é',
#   'coisa',
#   'de',
#   'branco',
#   'bombado',
#   'cabelo',
#   'liso',
#   'topete',
#   'na',
#   'frente',
#   'blusa',
#   'amarrada',
#   'no',
#   'braço',
#   'ou',
#   'entao',
#   'enfiada',
#   'no',
#   'bolso',
#   'da',
#   'bermudinha',
#   'j…'],
#  ['como',
#   'ficar',
#   'loca',
#   'ao',
#   'nível',
#   'de',
#   'mandar',
#   'eu',
#   'te',
#   'amo',
#   'pra',
#   'pessoas',
#   'aleatórias',
#   'com',
#   '1',
#   'garrafa',
#   'd',
#   'heineken',
#   'pesquisando'],
#  ['rt',
#   '@farrley_:',
#   'isso',
#   'é',
#   'coisa',
#   'de',
#   'branco',
#   'bombado',
#   'cabelo',
#   'liso',
#   'topete',
#   'na',
#   'frente',
#   'blusa',
#   'amarrada',
#   'no',
#   'braço',
#   'ou',
#   'entao',
#   'enfiada',
#   'no',
#   'bolso',
#   'da',
#   'bermudinha',
#   'j…'],
#  ['#vamosfalarsobrelúpulo',
#   'skol',
#   'tinha',
#   'que',
#   'falar',
#   'da',
#   '#festajunina',
#   'cerveja',
#   'de',
#   'milho....',
#   'pipoca',
#   'e',
#   'outros',
#   'derivados....',
#   '@heineken',
#   'é',
#   'bem',
#   'melhor....'],
#  ['mas',
#   'depois',
#   'eu',
#   'comi',
#   'um',
#   'lanchão',
#   'do',
#   'subway',
#   'e',
#   'fiquei',
#   'feliz',
#   '!!!!',
#   'chegar',
#   'em',
#   'casa',
#   'tem',
#   'um',
#   'fardo',
#   'de',
#   'heineken',
#   'me',
#   'esperando',
#   'e',
#   'o',
#   'melhor',
#   'uma',
#   'lasanha',
#   'da',
#   'mamis,',
#   'nem',
#   'dá',
#   'pra',
#   'ficar',
#   'estressada',
#   'com',
#   'o',
#   'simulado'],
#  ['rt',
#   '@manum_:',
#   'vejo',
#   'futuro',
#   'numa',
#   'tampinha',
#   'de',
#   'heineken.',
#   '(n',
#   '04)'],
#  ['rt',
#   '@farrley_:',
#   'isso',
#   'é',
#   'coisa',
#   'de',
#   'branco',
#   'bombado',
#   'cabelo',
#   'liso',
#   'topete',
#   'na',
#   'frente',
#   'blusa',
#   'amarrada',
#   'no',
#   'braço',
#   'ou',
#   'entao',
#   'enfiada',
#   'no',
#   'bolso',
#   'da',
#   'bermudinha',
#   'j…'],
#  ['rt',
#   '@farrley_:',
#   'isso',
#   'é',
#   'coisa',
#   'de',
#   'branco',
#   'bombado',
#   'cabelo',
#   'liso',
#   'topete',
#   'na',
#   'frente',
#   'blusa',
#   'amarrada',
#   'no',
#   'braço',
#   'ou',
#   'entao',
#   'enfiada',
#   'no',
#   'bolso',
#   'da',
#   'bermudinha',
#   'j…'],
#  ['rt',
#   '@gilvanroots:',
#   'domingo,',
#   'dia',
#   'de',
#   'moer',
#   'uns',
#   'cereais',
#   'e',
#   'beber',
#   'um',
#   'puro',
#   'malte.',
#   'o',
#   '2°',
#   'semestre',
#   'rasgando',
#   'como',
#   'um',
#   'iceberg',
#   'na',
#   'banheira',
#   'e',
#   '2018',
#   'vai',
#   'se',
#   'c…'],
#  ['só', 'uma', 'heineken', 'e', 'um', 'fifinha'],
#  ['rt',
#   '@farrley_:',
#   'isso',
#   'é',
#   'coisa',
#   'de',
#   'branco',
#   'bombado',
#   'cabelo',
#   'liso',
#   'topete',
#   'na',
#   'frente',
#   'blusa',
#   'amarrada',
#   'no',
#   'braço',
#   'ou',
#   'entao',
#   'enfiada',
#   'no',
#   'bolso',
#   'da',
#   'bermudinha',
#   'j…'],
#  ['@deftoneer',
#   'certamente',
#   'eu',
#   'contrataria',
#   '10',
#   'damas',
#   'da',
#   'noite,',
#   'compraria',
#   '10',
#   'barris',
#   'de',
#   'heineken,',
#   'compraria',
#   'uns',
#   '5',
#   'charutos',
#   'cubanos.',
#   'o',
#   'resto',
#   'eu',
#   'iria',
#   'torrar',
#   'com',
#   'supérfluos',
#   'como',
#   'poupança,',
#   'alimentos,',
#   'roupas',
#   'e',
#   'cursos.'],
#  ['rt',
#   '@farrley_:',
#   'isso',
#   'é',
#   'coisa',
#   'de',
#   'branco',
#   'bombado',
#   'cabelo',
#   'liso',
#   'topete',
#   'na',
#   'frente',
#   'blusa',
#   'amarrada',
#   'no',
#   'braço',
#   'ou',
#   'entao',
#   'enfiada',
#   'no',
#   'bolso',
#   'da',
#   'bermudinha',
#   'j…']]

# %%
def remocao_palavras_inteiras(lista):
    for e in range(0,len(lista)):
        for i in range(0,len(lista[e])):
            if lista[e][i][0] == '@' or lista[e][i][0:4] == 'http' or lista[e][i] == 'rt':
                lista[e][i] = 'lixo'
    for x in range(0,len(lista)):
        deletadas = 0
        for z in range(0,len(lista[x])):
            if lista[x][z - deletadas] == 'lixo':
                del lista[x][z - deletadas]
                deletadas += 1
                
    return lista

# %%
def remocao_acentos(lista):
    e = ['é','è','ê']
    a = ['á','à','ã','â']
    i = ['í','ì','î']
    o = ['ó','ò','õ','ô']
    u = ['ú','ù','û']
    for x in range(0,len(lista)):
        for y in range(0,len(lista[x])):
            for l in range(0,len(lista[x][y])):
                if lista[x][y][l] in e:
                    divide = list(lista[x][y])
                    divide[l] = 'e'
                    lista[x][y] = ''.join(divide)
                    break
                elif lista[x][y][l] in a:
                    divide = list(lista[x][y])
                    divide[l] = 'a'
                    lista[x][y] = ''.join(divide)
                    break
                elif lista[x][y][l] in i:
                    divide = list(lista[x][y])
                    divide[l] = 'i'
                    lista[x][y] = ''.join(divide)
                    break
                elif lista[x][y][l] in o:
                    divide = list(lista[x][y])
                    divide[l] = 'o'
                    lista[x][y] = ''.join(divide)
                    break
                elif lista[x][y][l] in u:
                    divide = list(lista[x][y])
                    divide[l] = 'u'
                    lista[x][y] = ''.join(divide)
                    break
                         
    return lista

# %%
def remocao_caracteres(lista):

    caracteres = ['\\',',','+','@','#',"'","\"","!","(",")",'...','$','-','/','?','.',',',';',':']
    for e in range(0,len(lista)):
        for i in range(0,len(lista[e])):
            for l in range(0,len(lista[e][i])):
                if lista[e][i][l] in caracteres:
                    divide = list(lista[e][i])
                    del divide[l]
                    lista[e][i] = ''.join(divide)
                    break
                    
    return lista

# %%
def normalizacao(objeto):
    x = lista(objeto)
    y = remocao_palavras_inteiras(x)
    z = remocao_caracteres(y)
    finalizado = remocao_acentos(z)
    return finalizado

# %%
def contagem(lista):
    dicionario = {}
    for e in range(0,len(lista)):
        for i in range(0,len(lista[e])):
            if lista[e][i] not in dicionario:
                dicionario[lista[e][i]] = 1
            else:
                dicionario[lista[e][i]]+=1
    return dicionario

# %%
def preparacao_final(objeto):
    x = normalizacao(objeto)
    final = contagem(x)
    return final

# %%
tudo_treinamento_final = preparacao_final(tudo_treino)
treinamento_relevante_final = preparacao_final(treino_uteis)
treinamento_irrelevante_final = preparacao_final(treino_indiferente)

# %%
def soma(dicionario):
    contador = 0
    for e in dicionario:
        contador += dicionario[e]
    return contador

# %%
soma_total = soma(tudo_treinamento_final)
soma_relevantes = soma(treinamento_relevante_final)
soma_irrelevante = soma(treinamento_irrelevante_final)
if 'gostam' not in treinamento_irrelevante_final:
    print('olodum')
# Out:
# olodum

# %% [markdown]
# ### Calculando a probabilidade da frase ser relevante ou não

# %%
def relevancia(tweet):
    tweet_separado = tweet.split()
    P_frase_relevante = 1
    P_frase_irrelevante = 1
    for e in tweet_separado:
        if e not in treinamento_relevante_final:
            P_frase_relevante += 1
        else:   
            P_frase_relevante *= (treinamento_relevante_final[e] + 1)/(soma_relevantes + len(tudo_treinamento_final))
        if e not in treinamento_irrelevante_final:
            P_frase_irrelevante +=1
        else:
            P_frase_irrelevante *= (treinamento_irrelevante_final[e] + 1)/(soma_irrelevante + len(tudo_treinamento_final))
    if P_frase_irrelevante > P_frase_relevante:
            return 'irrelevante'
    else:
            return 'relevante'

# %% [markdown]
# ___
# ## Verificando a performance
#
# Agora você deve testar o seu Classificador com a base de Testes.<br /><br />
#
# Você deve extrair as seguintes medidas:
# * Porcentagem de positivos falsos (marcados como relevante mas não são relevantes)
# * Porcentagem de positivos verdadeiros (marcado como relevante e são relevantes)
# * Porcentagem de negativos verdadeiros (marcado como não relevante e não são relevantes)
# * Porcentagem de negativos falsos (marcado como não relevante e são relevantes)
#
# Obrigatório para grupos de 3 alunos:
# * Criar categorias intermediárias de relevância baseado na diferença de probabilidades. Exemplo: muito relevante, relevante, neutro, irrelevante e muito irrelevante.

# %% [markdown]
# ### Limpando os comentários do teste

# %%
teste_completo_limpo = normalizacao(tudo_teste)
lista_final = []
for e in range(0,len(teste_completo_limpo)):
    x = ' '.join(teste_completo_limpo[e])
    lista_final.append(x)

# %% [markdown]
# ### Classificando

# %%
lista_resposta = []
for e in lista_final:
    x = relevancia(e)
    if x == 'relevante':
        lista_resposta.append(0)
    else:
        lista_resposta.append(2)

# %%
classificacao_teste = teste.classificacao # classificacao humana
positivo_falso = 0
positivo_verdadeiro = 0
negativo_verdadeiro = 0
negativo_falso = 0
for e in range(0,200):
    if lista_resposta[e] == 2 and classificacao_teste[e] == 2:
        negativo_verdadeiro +=1
    elif lista_resposta[e] == 2 and classificacao_teste[e] != 2:
        negativo_falso += 1
    elif lista_resposta[e] == 0 and classificacao_teste[e] != 2:
        positivo_verdadeiro += 1
    elif lista_resposta[e] == 0 and classificacao_teste[e] == 2:
        positivo_falso += 1
        
porcentagem_pos_fal = positivo_falso/200
porcentagem_pos_ver = positivo_verdadeiro/200
porcentagem_neg_fal = negativo_falso/200
porcentagem_neg_ver = negativo_verdadeiro/200

print(porcentagem_neg_fal)
print(porcentagem_neg_ver)
print(porcentagem_pos_fal)
print(porcentagem_pos_ver)
# Out:
# 0.585
# 0.2
# 0.105
# 0.11

# %%
certo = 0
errado = 0
for e in range(0,200):
    if lista_resposta[e] == 2 and classificacao_teste[e] == 2:
        certo+=1
    elif lista_resposta[e] == 0 and classificacao_teste[3] != 2:
        certo+=1
    else:
        errado+=1
print(certo/200,errado/200)
# Out:
# 0.415 0.585

# %% [markdown]
# ___
# ## Concluindo
#
# Escreva aqui a sua conclusão.<br />
# Faça um comparativo qualitativo sobre as medidas obtidas.<br />
# Explique como são tratadas as mensagens com dupla negação e sarcasmo.<br />
# Proponha um plano de expansão. Por que eles devem continuar financiando o seu projeto?<br />
#
# Opcionalmente:
# * Discorrer por que não posso alimentar minha base de Treinamento automaticamente usando o próprio classificador, aplicado a novos tweets.
# * Propor diferentes cenários de uso para o classificador Naive-Bayes. Cenários sem intersecção com este projeto.
# * Sugerir e explicar melhorias reais no classificador com indicações concretas de como implementar (não é preciso codificar, mas indicar como fazer e material de pesquisa sobre o assunto).

# %% [markdown]
# Concluimos que o nosso classificador não conseguiu chegar ao nivel de acurácia que esperavamos na análise dos tweets que nós mesmo classificamos.
#
# Nossas precisao foi mais baixa do que esperavamos (41,5%), isso pode ter acontecido pelo fato de haver muitos tweets que envolvem sarcasmo, deste modo como nosso classificador é muito primitivo ele ainda não detecta este fator nas frases e também outra razão pode ser o fato da impressicão da classificação humana, uma vez que esses dependem de interpretações pessoais e esse trabalho foi dividido por nós, o que aumenta ainda mais a imprecisão do sistema.
#
# A detecção de sarcasmo pode ser o plano de expansao, uma vez que aumentaria a precisão do classificador, assim podendo ser mais utilizado em outras funções. Além disso outro plano seria classificar mais tweets na mão, uma vez que isso aumentaria a base de dados e por consequencia a precisão
#
# Este classificador pode ser usado em empresas pequenas, que não necessitam de um alto nivel de precisão e que muitas vezes o número de tweets envolvendo elas é menor e assim tendo menos problemas envolvendo a interpretação do classificador.
